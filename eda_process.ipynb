# %%
import pandas as pd
import numpy as np

# %%
#reformating of .csv format in order to be usable
df = pd.read_csv("datasets/effectifs.csv",sep=';')

# %%
df.head()
# Out:
#    annee                                         patho_niv1      patho_niv2  \
# 0   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#       patho_niv3          top cla_age_5  sexe  region dept  Ntop   Npop  prev  \
# 0  Mucoviscidose  RAR_MUC_IND     95et+     9      28  999   NaN  15550   NaN
# 1  Mucoviscidose  RAR_MUC_IND     95et+     9      32   59   NaN   8460   NaN
# 2  Mucoviscidose  RAR_MUC_IND     95et+     9      32   60   NaN   2470   NaN
# 3  Mucoviscidose  RAR_MUC_IND     95et+     9      32   62   NaN   5010   NaN
# 4  Mucoviscidose  RAR_MUC_IND     95et+     9      32   80   NaN   2220   NaN
#
# ...

# %%
#allows use to know the type of the value contained in each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5216400 entries, 0 to 5216399
# Data columns (total 16 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   annee               int64
#  1   patho_niv1          object
#  2   patho_niv2          object
#  3   patho_niv3          object
#  4   top                 object
#  5   cla_age_5           object
#  6   sexe                int64
#  7   region              int64
#  8   dept                object
#  9   Ntop                float64
#  10  Npop                int64
#  11  prev                float64
#  12  Niveau prioritaire  object
#  13  libelle_classe_age  object
#  14  libelle_sexe        object
#  15  tri                 float64
# dtypes: float64(3), int64(4), object(9)
# memory usage: 636.8+ MB

# %%
df["Ntop"].notnull().sum()
# Out:
# np.int64(3833965)

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df.describe()
# Out:
#            annee       sexe     region        Ntop        Npop       prev  \
# count 5216400.00 5216400.00 5216400.00  3833965.00  5216400.00 3833965.00
# mean     2019.00       4.08      51.05     5544.95   103235.19       6.22
# std         2.58       3.58      29.45   159030.85   989288.23      15.95
# min      2015.00       1.00       1.00       10.00       10.00       0.00
# 25%      2017.00       1.00      27.00       50.00     7710.00       0.27
# 50%      2019.00       2.00      52.00      200.00    17040.00       0.98
# 75%      2021.00       9.00      76.00      950.00    42670.00       4.21
# max      2023.00       9.00      99.00 68833510.00 68833510.00     100.00
#
#              tri
# count 5148360.00
# mean       39.41
# std        22.52
# min         1.00
# 25%        20.00
# 50%        39.00
# 75%        58.00
# max        78.00

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df , x="cla_age_5")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(data=df , x="patho_niv1")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_27650/2733448896.py:4: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
df.head()
# Out:
#    annee                                         patho_niv1      patho_niv2  \
# 0   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#       patho_niv3          top cla_age_5  sexe  region dept  Ntop   Npop  prev  \
# 0  Mucoviscidose  RAR_MUC_IND     95et+     9      28  999   NaN  15550   NaN
# 1  Mucoviscidose  RAR_MUC_IND     95et+     9      32   59   NaN   8460   NaN
# 2  Mucoviscidose  RAR_MUC_IND     95et+     9      32   60   NaN   2470   NaN
# 3  Mucoviscidose  RAR_MUC_IND     95et+     9      32   62   NaN   5010   NaN
# 4  Mucoviscidose  RAR_MUC_IND     95et+     9      32   80   NaN   2220   NaN
#
# ...

# %%
#selction of targeted data
df = df[["annee" , "patho_niv1" ,"patho_niv2","patho_niv3","libelle_classe_age","sexe","dept","Ntop","Npop"]]

# %%
df.head()
# Out:
#    annee                                         patho_niv1      patho_niv2  \
# 0   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#       patho_niv3 libelle_classe_age  sexe dept  Ntop   Npop
# 0  Mucoviscidose     plus de 95 ans     9  999   NaN  15550
# 1  Mucoviscidose     plus de 95 ans     9   59   NaN   8460
# 2  Mucoviscidose     plus de 95 ans     9   60   NaN   2470
# 3  Mucoviscidose     plus de 95 ans     9   62   NaN   5010
# 4  Mucoviscidose     plus de 95 ans     9   80   NaN   2220

# %%
df["Ntop"].fillna(5,inplace=True)
# In accordance with statistical confidentiality laws (law of June 7, 1951) and to ensure that individuals cannot be directly or indirectly identified, no information on patient numbers is disclosed when the number of patients treated is less than 10. 
# Looking at this information we have decided to fix at 5 the number Ntop filed with NaN
# Out:
# /tmp/ipykernel_27650/895835740.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Ntop"].fillna(5,inplace=True)

# %%
df.head()
# Out:
#    annee                                         patho_niv1      patho_niv2  \
# 0   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 1   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 2   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 3   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
# 4   2023  Maladies inflammatoires ou rares ou infection VIH  Maladies rares
#
#       patho_niv3 libelle_classe_age  sexe dept  Ntop   Npop
# 0  Mucoviscidose     plus de 95 ans     9  999  5.00  15550
# 1  Mucoviscidose     plus de 95 ans     9   59  5.00   8460
# 2  Mucoviscidose     plus de 95 ans     9   60  5.00   2470
# 3  Mucoviscidose     plus de 95 ans     9   62  5.00   5010
# 4  Mucoviscidose     plus de 95 ans     9   80  5.00   2220

# %%
def get_age(x:str) -> int: 
    splitted = x.split()
    number_list = []
    for n in splitted:
        if n.isdigit():
            number_list.append(int(n))
    if len(number_list) == 0:
        return np.nan
    minimal_value = min(number_list)
    return int(minimal_value)
    
get_age("De 50 à 59 ans")
# Out:
# 50

# %%
sns.countplot(data=df , y="libelle_classe_age")
# plt.yticks(rotation=90)
plt.show()

# %%
df["min_age"] = df["libelle_classe_age"].apply(get_age)
df = df[df["sexe"] != 9]

# %%
vals = [
    "Maladies neurologiques",
    'Traitements psychotropes (hors pathologies)',
    "Maladies psychiatriques",
    "Affections de longue durée (dont 31 et 32) pour d'autres causes"
]

df_filtered = df[df["patho_niv1"].isin(vals)]

# %%
df["patho_niv1"].unique()
# Out:
# array(['Maladies inflammatoires ou rares ou infection VIH',
#        'Maladies neurologiques', 'Maladies psychiatriques',
#        'Pas de pathologie repérée, traitement, maternité, hospitalisation ou traitement antalgique ou anti-inflammatoire',
#        'Total consommants tous régimes',
#        'Traitements du risque vasculaire (hors pathologies)',
#        'Traitements psychotropes (hors pathologies)',
#        'Maladies cardioneurovasculaires',
#        'Maladies respiratoires chroniques (hors mucoviscidose)',
#        'Traitements antalgiques ou anti-inflammatoires (hors pathologies, traitements, maternité ou hospitalisations)',
#        'Maladies du foie ou du pancréas (hors mucoviscidose)',
#        'Maternité (avec ou sans pathologies)',
#        'Insuffisance rénale chronique terminale',
#        'Hospitalisations hors pathologies repérées (avec ou sans pathologies, traitements ou maternité)',
#        'Cancers', 'Diabète', 'Hospitalisation pour Covid-19',
# ...

# %%
df_filtered["patho_niv1"].unique()
# Out:
# array(['Maladies neurologiques', 'Maladies psychiatriques',
#        'Traitements psychotropes (hors pathologies)',
#        "Affections de longue durée (dont 31 et 32) pour d'autres causes"],
#       dtype=object)

# %%
df_filtered.head()
# Out:
#      annee              patho_niv1 patho_niv2 patho_niv3 libelle_classe_age  \
# 147   2023  Maladies neurologiques        NaN        NaN       de 0 à 4 ans
# 148   2023  Maladies neurologiques        NaN        NaN       de 0 à 4 ans
# 149   2023  Maladies neurologiques        NaN        NaN       de 0 à 4 ans
# 150   2023  Maladies neurologiques        NaN        NaN       de 0 à 4 ans
# 151   2023  Maladies neurologiques        NaN        NaN       de 0 à 4 ans
#
#      sexe dept   Ntop   Npop  min_age
# 147     1  999  60.00   8340     0.00
# 148     1  973  50.00  11110     0.00
# 149     1  999  50.00  11110     0.00
# 150     1  976  20.00   9960     0.00
# 151     1   92 160.00  48540     0.00

# %%
# df_filtered.dropna()

# %%
# #Graph n°1 evolution of the mental health between 2015 - 2023 
# def somme_npop_par_annee(df):
#     """
#     Calcule la somme de Npop pour chaque année
#     et retourne une série pandas.
#     """
#     return df.groupby("annee")["Npop"].sum()

# def tracer_evolution_npop(df):
#     """
#     Trace la courbe de l'évolution de la somme de Npop par année.
#     """
#     serie = somme_npop_par_annee(df)

#     plt.figure(figsize=(8,5))
#     plt.plot(serie.index, serie.values, marker='o')
#     plt.xlabel("Année")
#     plt.ylabel("Somme de Npop")
#     plt.title("Évolution de la somme de Npop par année")
#     plt.grid(True)
#     plt.show()
# tracer_evolution_npop(df)

# %%
df_filtered.groupby(["patho_niv1", "annee"]).size().head(20)
# Out:
# patho_niv1                                                       annee
# Affections de longue durée (dont 31 et 32) pour d'autres causes  2015      5040
#                                                                  2016      5040
#                                                                  2017      5040
#                                                                  2018      5040
#                                                                  2019      5040
#                                                                  2020      5040
#                                                                  2021      5040
#                                                                  2022      5040
#                                                                  2023      5040
# Maladies neurologiques                                           2015     40320
#                                                                  2016     40320
# ...

# %%
# df3 = df_filtered.groupby(["patho_niv1", "annee"])["Ntop"].sum().reset_index()
# df3

# %%
# plt.figure(figsize=(12,6))
# sns.lineplot(data=df3 , x="annee" , y="Ntop" , hue="patho_niv1",marker='o')

# %%
df_year = df_filtered.groupby(["patho_niv1", "annee"]).apply(
    lambda g: g["Ntop"].sum() / g["Npop"].sum()
).reset_index(name="prevalence")

df_year["prevalence (%)"] = df_year["prevalence"] * 100
# Out:
# /tmp/ipykernel_27650/3857279387.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_year = df_filtered.groupby(["patho_niv1", "annee"]).apply(

# %%
df_filtered.groupby(["patho_niv1", "annee", "libelle_classe_age", "sexe"]).size().nunique()
# Out:
# 4

# %%
df_filtered.groupby(["patho_niv1", "annee", "libelle_classe_age", "sexe"])["Ntop"].count().describe()
# Out:
# count   1512.00
# mean     630.00
# std      321.82
# min      120.00
# 25%      480.00
# 50%      720.00
# 75%      870.00
# max      960.00
# Name: Ntop, dtype: float64
